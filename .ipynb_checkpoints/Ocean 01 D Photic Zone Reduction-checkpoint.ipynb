# %% [markdown]
# # Photic Zone: Low-data-rate sensor profile reduction
#
#
# Profiler sensors produce profiles that can be described approximately with a few parameters. This notebook takes up
# this simplification / reduction process starting again with CTD data. See notebook Ocean 01 A for the source material.

# %%
import os, sys, time, glob, warnings
from IPython.display import clear_output             # use inside loop with clear_output(wait = True) followed by print(i)
warnings.filterwarnings('ignore')
this_dir = os.getcwd()
data_dir = this_dir + '/../data'

from matplotlib import pyplot as plt
from matplotlib import colors as mplcolors
import numpy as np, pandas as pd, xarray as xr
from numpy import datetime64 as dt64, timedelta64 as td64

# convenience functions abbreviating 'datetime64' and so on
def doy(theDatetime): return 1 + int((theDatetime - dt64(str(theDatetime)[0:4] + '-01-01')) / td64(1, 'D'))
def dt64_from_doy(year, doy): return dt64(str(year) + '-01-01') + td64(doy-1, 'D')
def day_of_month_to_string(d): return str(d) if d > 9 else '0' + str(d)

print('\nJupyter Notebook running Python {}'.format(sys.version_info[0]))
# Out:
# Jupyter Notebook running Python 3

# %% [markdown]
# ### to do
#
# - Improve the Profile class
# - Bring in kwargs for functions
# - Write up re-naming Datasets / DataArrays / components
# - Plotting and Widgets
#     - Animations
#     - Dual sliders for first profile and number of profiles; left and right so 4 total
#     - Program logic pushes back on slider settings? widget fu
#     - Make the filter parameter and the ranges arrays
#     - It would be pleasant to suffer less filter damage from NaNs (widening dropout)
# - DONE: Crawler indices for start/stop ascent/descent/rest
#     - Publish crawler results to a table
#     - Extend the time range to all of 2014 - 2021
#     - annotate the pH stops: both midnight and noon local, include that in the publication
#     - are rests are accurately picked up in other time ranges
# - Derivatives
#     - attach the derivative plots to the main data
#     - plot zero line for zero crossings in the derivative plots, flag those
# - Characterization by (sensor type, ascent/descent, continuous/interval, night/day)...
#     - Extract the data with time and depth
#     - Smooth the data
#     - Calculate first and second derivatives
#     - Calculate a set of characterization values
#         - Start depth
#         - Depth at which signal slope (low pass) changes
#         - Inflection
#         - Max slope
#         - Upper layer thickness
#         - Boxcar standard deviation
#         - And like that; and infer lenses if they are present
#     - Revisit the down-sampling to one minute and the stddev signal
# - Dimension is now roughly speaking a collection of profiles by sensors
#     - Compare same profile different sensors
#     - Compare different profile same sensors
#     - Review the Arctic Great Rivers data in the sense of "29-observation axis"

# %%
def filter(v, ftype='hat', control1=3):
    """Operate on an XArray data array (with some checks) to produce a filtered version"""
    # pre-checks
    if not v.dims[0] == 'time': return v

    if ftype == 'hat': 
        n_passes = control1        # should be a kwarg
        len_v = len(v)
        for n in range(n_passes):
            source_data = np.copy(v) if n == 0 else np.copy(smooth_data)
            smooth_data = [source_data[i] if i == 0 or i == len_v - 1 else \
                0.5 * source_data[i] + 0.25 * (source_data[i-1] + source_data[i + 1]) \
                for i in range(len_v)]
        return smooth_data
    return v

def pull_data_array_by_name(ds, sensor_name):
    """completely extraneous (Delete Me) function"""
    return ds['sensor_name']

def dydx(y, x):
    """
    This is a simple 'centered' derivative: At location n it uses values at (n-1) and (n+1).
    Endpoints are hardcoded to zero so to do make them proper estimates.
    The sign +- also to do should be handled properly; varies with direction of profile up / down
    """ 
    len_y = len(y)
    return [0. if i == 0 or i == len_y - 1 else -(y[i+1] - y[i-1])/(x[i+1] - x[i-1]) for i in range(len_y)]

def ProfileCrawler(ds, verbose = False):
    """
    Walk a passed dataset to pin profiler start / stop times based on pressure
    """

    s = ds.seawater_pressure.to_series()         # pandas series, just pressure (and times)
    len_s = len(s)

    ascent_starts  = np.zeros(len_s)
    descent_starts = np.zeros(len_s)
    rest_starts    = np.zeros(len_s)
    
    threshold, nA0, nD0, nR0 = 1., 0, 0, 0

    for i in range(1, len_s - 5):         # 6 minute window
        
        # catch ascent
        if s[i-1] - s[i]   <= threshold and  \
           s[i]   - s[i+1] >= threshold and  \
           s[i+1] - s[i+2] >= threshold and  \
           s[i+2] - s[i+3] >= threshold and  \
           s[i+3] - s[i+4] >= threshold and  \
           s[i+4] - s[i+5] >= threshold:
            ascent_starts[i] = True
            nA0 += 1

        # catch descent
        if s[i-1] - s[i]   >= threshold and  \
           s[i]   - s[i+1] <= threshold and  \
           s[i+1] - s[i+2] <= threshold and  \
           s[i+2] - s[i+3] <= threshold and  \
           s[i+3] - s[i+4] <= threshold and  \
           s[i+4] - s[i+5] <= threshold:
            descent_starts[i] = True
            nD0 += 1
        
        # this variant is a little too liberal; false positives ~25%
        # why? Because twice daily there are stops on the way down for pH
        # catch rest
        if i >= 5 and \
           s[i-5] - s[i-4] <= -threshold and  \
           s[i-4] - s[i-3] <= -threshold and  \
           s[i-3] - s[i-2] <= -threshold and  \
           s[i-2] - s[i-1] <= -threshold and  \
           s[i-1] - s[i]   <= -threshold and  \
           s[i]   - s[i+1] >= -threshold:
            rest_starts[i] = True
            nR0 += 1
            
    if verbose: print(nA0, nD0, nR0)

    # These are index-accurate float-bool numpy arrays
    return ascent_starts, descent_starts, rest_starts

# %%
# ds_CTD is a Dataset with 44640 values, one per minute for January 2019
# ds_CTD.data_vars -> seawater_temperature, seawater_pressure, practical_salinity, corrected_dissolved_oxygen, density
# There should be 279 profiles; but 278 were found. The last profile of the month did not go.

# This file read is recapitulated below to keep this code independent of that code
osb_ctd_nc_file = "./data/rca/ctd/osb_ctd_jan2019_1min.nc"
ds_CTD = xr.open_dataset(osb_ctd_nc_file)

ascent_starts, descent_starts, rest_starts = ProfileCrawler(ds_CTD)

ascent0, ascent1, descent0, descent1, rest0, rest1 = [], [], [], [], [], []

for i in range(len(ascent_starts)): 
    if ascent_starts[i]:  ascent0.append(i)
    if descent_starts[i]: descent0.append(i)
        
        
# above is reliable for Jan 2019
# rest0[] indices must disambiguate descent stops on midn/noon profiles favoring the last one
counter = 0       # will tracks profile index
                  # rest_starts[] is minute by minute with ones at possible rest starts
                  # descent0 already filled in with indices acting as "counter+1" stop i-indices 
                 
for i in range(len(ascent_starts)):   # one minute at a time
    if rest_starts[i] and i > descent0[counter]:    # this is a candidate i-value for rest0[]
                                                    # it assumes the first rest follows the first descent
        found_a_later_candidate = False
        j_loop_upper = descent0[counter + 1] if counter < len(ascent0) - 1 else len(ascent_starts)
        for j in range(i+1, j_loop_upper):
            if rest_starts[j]: found_a_later_candidate = True
        if not found_a_later_candidate:
            rest0.append(i)
            counter += 1
        
ascent1  = descent0.copy()
descent1 = rest0.copy()
rest1    = ascent0[1:].copy()
rest1.append(len(ascent_starts)-1)

# Use this to check the ordering
# for i in range(10): print(ascent0[i], ascent1[i], descent0[i], descent1[i], rest0[i], rest1[i])

# use this to check order logic for the full series
for i in range(len(ascent0)):
    if ascent0[i] >= descent0[i]: print('err 1', i)
    if descent0[i] >= rest0[i]: print('err 2', i)
    if ascent1[i] >= descent1[i]: print('err 3', i)
    if descent1[i] >= rest1[i]: print('err 4', i)

# at this point ideally all six index lists are the same length
print(len(ascent0), len(descent0), len(rest0), len(ascent1), len(descent1), len(rest1))

# the last values show rest1 ends at the last index of the source data 
# print(ascent0[-1], ascent1[-1])
# print(descent0[-1], descent1[-1])
# print(rest0[-1], rest1[-1])
# Out:
# 278 278 278 278 278 278

# %%
delta_ascent  = [ascent1[i] - ascent0[i] + 1 for i in range(len(ascent0))]
delta_descent = [descent1[i] - descent0[i] + 1 for i in range(len(descent0))]
delta_rest    = [rest1[i] - rest0[i] + 1 for i in range(len(rest0))]

print('Means, standard deviations for profile phases (minutes):')
print('  Ascent time:', round(np.mean(delta_ascent), 2), round(np.std(delta_ascent), 2))
print('  Descent time:', round(np.mean(delta_descent), 2), round(np.std(delta_descent), 2))
print('  Rest time:', round(np.mean(delta_rest[0:-1]), 2), round(np.std(delta_rest[0:-1]), 2))
print()
print('(Recall that two profiles of nine each day have slower, staged descents)')
print()
# print(delta_rest[-1])
# Out:
# Means, standard deviations for profile phases (minutes):
#   Ascent time: 68.42 3.01
#   Descent time: 48.54 24.88
#   Rest time: 45.81 14.05
#
# (Recall that two profiles of nine each day have slower, staged descents)

# %% [markdown]
# ## Data charting part 1: six signals, one profile
#
# The segment below builds on this using a selector-slider widget.

# %%
# loading CTD/DO + nitrate + fluorometer by copy/paste from nbk 01 A

osb_ctd_nc_file = "./data/rca/ctd/osb_ctd_jan2019_1min.nc"
ds_CTD = xr.open_dataset(osb_ctd_nc_file)

nitrate_source = './data/rca/nitrate/'
nitrate_data_midnight = 'nc_midn_2019_01.nc'
nitrate_data_noon     = 'nc_noon_2019_01.nc'

ds_nitrate_midn = xr.load_dataset(nitrate_source + nitrate_data_midnight)
ds_nitrate_noon = xr.load_dataset(nitrate_source + nitrate_data_noon)

fluorometer_source = './data/rca/fluorescence/'
fluorometer_data = 'osb_sp_fluor_jan2019.nc'
ds_Fluorometer = xr.open_dataset(fluorometer_source + fluorometer_data)

ds_CTD
# Out:
# <xarray.Dataset>
# Dimensions:                     (time: 44640)
# Coordinates:
#   * time                        (time) datetime64[ns] 2019-01-01 ... 2019-01-...
# Data variables:
#     seawater_temperature        (time) float64 ...
#     seawater_pressure           (time) float64 ...
#     practical_salinity          (time) float64 ...
#     corrected_dissolved_oxygen  (time) float64 ...
#     density                     (time) float64 ...
# Attributes:
#     node:                SF01A
#     id:                  RS01SBPS-SF01A-2A-CTDPFA102-streamed-ctdpf_sbe43_sample
#     geospatial_lat_min:  44.52897
#     geospatial_lon_min:  -125.38966

# %% [markdown]
# Design the the crawler output table...
#
# ```
# type,     t0,               t1,                d0,         d1,     i0,         i1,           midn,        noon,
# ascent,   2019-01-01T00:27, 2019-01-01T01:37   191.4,      6.78,   21,         91,           False,       False,
# descent,                                                           91,         138,          False,       False,
# rest,                                                              138,        168,          False,       False,
# ascent,                                                                                      True,        False,
# descent,                                                                                     True,        False,
# rest,                                                                                        True,        False,
# ascent,                                                                                      False,       False,
# descent,                                                                                     False,       False,
# rest,                                                                                        False,       False,
# ```

# %%
time0, time1 = dt64('2019-01-01T00:26:05'), dt64('2019-01-01T01:37:55')
ds_CTD_time_slice = ds_CTD.sel(time=slice(time0, time1))
ds_fluor_time_slice = ds_Fluorometer.sel(time=slice(time0, time1))

ctd_t = ds_CTD_time_slice['seawater_temperature'];       smooth_ctd_t = filter(ctd_t)
ctd_s = ds_CTD_time_slice['practical_salinity'];         smooth_ctd_s = filter(ctd_s)
ctd_o = ds_CTD_time_slice['corrected_dissolved_oxygen']; smooth_ctd_o = filter(ctd_o)

ctd_d = ds_CTD_time_slice['seawater_pressure']

fluor_a = ds_fluor_time_slice['fluorometric_chlorophyll_a'];          smooth_fluor_a = filter(fluor_a)
fluor_c = ds_fluor_time_slice['fluorometric_cdom'];                   smooth_fluor_c = filter(fluor_c)
fluor_s = ds_fluor_time_slice['total_volume_scattering_coefficient']; smooth_fluor_s = filter(fluor_s)

fluor_d = ds_fluor_time_slice['int_ctd_pressure']

temperature_lbound, temperature_ubound           =   8.,        12.
salinity_lbound, salinity_ubound                 =  32.,        34.
dissolved_oxygen_lbound, dissolved_oxygen_ubound = 100.,       300.
chlora_lbound, chlora_ubound                     =  -1.,         2.
cdom_lbound, cdom_ubound                         =   1.2,        2.2
scatt_lbound, scatt_ubound                       =   0.000075,    .00035

fig, axs = plt.subplots(6,1,figsize=(15, 15), tight_layout=True)

compare_unfiltered = False

if compare_unfiltered:
    axs[0].plot(ctd_t + 0.5, ctd_d, marker='o', markersize = 6., color='k', markerfacecolor='r')
    axs[1].plot(ctd_s + 0.5, ctd_d, marker='s', markersize = 6., color='g', markerfacecolor='r')
    axs[2].plot(ctd_o + 20., ctd_d, marker='D', markersize = 6., color='b', markerfacecolor='r')
    axs[3].plot(fluor_a + 0.5, fluor_d, marker='o', markersize = 6., color='k', markerfacecolor='r')
    axs[4].plot(fluor_c + 0.5, fluor_d, marker='s', markersize = 6., color='g', markerfacecolor='r')
    axs[5].plot(fluor_s + 20., fluor_d, marker='D', markersize = 6., color='b', markerfacecolor='r')

axs[0].plot(smooth_ctd_t, ctd_d, marker='o', markersize = 6., color='k', markerfacecolor='c')
axs[0].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')

axs[1].plot(smooth_ctd_s, ctd_d, marker='s', markersize = 6., color='g', markerfacecolor='m')
axs[1].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')

axs[2].plot(smooth_ctd_o, ctd_d, marker='D', markersize = 6., color='b', markerfacecolor='y')
axs[2].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')

axs[3].plot(smooth_fluor_a, fluor_d, marker='o', markersize = 6., color='k', markerfacecolor='c')
axs[3].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')

axs[4].plot(smooth_fluor_c, fluor_d, marker='s', markersize = 6., color='g', markerfacecolor='m')
axs[4].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')

axs[5].plot(smooth_fluor_s, fluor_d, marker='D', markersize = 6., color='b', markerfacecolor='y')
axs[5].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')

# sets up companion plots with shared y-axis, independent 'twin' x-axis
axsTwin = [axs[i].twiny() for i in range(6)]
axsTwin[0].set_xlabel('cdom', color='g')
axsTwin[0].plot(smooth_fluor_c, fluor_d, marker='s', markersize = 6., color='g', markerfacecolor='m')
axsTwin[0].tick_params(axis='x', labelcolor='g')
axsTwin[0].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.))

print('...')
# Out:
# ...

# %% [markdown]
# ## animating the time series
#
# The following tries to make an animation by scrolling through all 278 profiles per above. I moved the charts around
# to make the layout easier to see all at once; CTD on the left and Fluorometer on the right.

# %%
def ShowSixCharts(n):
    
    time0, time1 = dt64(ds_CTD.time[ascent0[n]].data), dt64(ds_CTD.time[ascent1[n]].data)
    ds_CTD_time_slice = ds_CTD.sel(time=slice(time0, time1))
    ds_fluor_time_slice = ds_Fluorometer.sel(time=slice(time0, time1))

    ctd_t = ds_CTD_time_slice['seawater_temperature'];       smooth_ctd_t = filter(ctd_t)
    ctd_s = ds_CTD_time_slice['practical_salinity'];         smooth_ctd_s = filter(ctd_s)
    ctd_o = ds_CTD_time_slice['corrected_dissolved_oxygen']; smooth_ctd_o = filter(ctd_o)

    ctd_d = ds_CTD_time_slice['seawater_pressure']

    fluor_a = ds_fluor_time_slice['fluorometric_chlorophyll_a'];          smooth_fluor_a = filter(fluor_a)
    fluor_c = ds_fluor_time_slice['fluorometric_cdom'];                   smooth_fluor_c = filter(fluor_c)
    fluor_s = ds_fluor_time_slice['total_volume_scattering_coefficient']; smooth_fluor_s = filter(fluor_s)

    fluor_d = ds_fluor_time_slice['int_ctd_pressure']

    temperature_lbound, temperature_ubound           =   8.,        12.
    salinity_lbound, salinity_ubound                 =  32.,        34.
    dissolved_oxygen_lbound, dissolved_oxygen_ubound = 100.,       300.
    chlora_lbound, chlora_ubound                     =  -1.,         2.
    cdom_lbound, cdom_ubound                         =   1.2,        2.2
    scatt_lbound, scatt_ubound                       =   0.000075,    .00035

    fig, axs = plt.subplots(3, 2, figsize=(9, 9), tight_layout=True)

    compare_unfiltered = False

    if compare_unfiltered:
        axs[0][0].plot(ctd_t + 0.5, ctd_d, marker='o', markersize = 6., color='k', markerfacecolor='r')
        axs[1][0].plot(ctd_s + 0.5, ctd_d, marker='s', markersize = 6., color='g', markerfacecolor='r')
        axs[2][0].plot(ctd_o + 20., ctd_d, marker='D', markersize = 6., color='b', markerfacecolor='r')
        axs[0][1].plot(fluor_a + 0.5, fluor_d, marker='o', markersize = 6., color='k', markerfacecolor='r')
        axs[1][1].plot(fluor_c + 0.5, fluor_d, marker='s', markersize = 6., color='g', markerfacecolor='r')
        axs[2][1].plot(fluor_s + 20., fluor_d, marker='D', markersize = 6., color='b', markerfacecolor='r')

    axs[0][0].plot(smooth_ctd_t, ctd_d, marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[0][0].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')

    axs[1][0].plot(smooth_ctd_s, ctd_d, marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[1][0].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')

    axs[2][0].plot(smooth_ctd_o, ctd_d, marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[2][0].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')

    axs[0][1].plot(smooth_fluor_a, fluor_d, marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[0][1].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')

    axs[1][1].plot(smooth_fluor_c, fluor_d, marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[1][1].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')

    axs[2][1].plot(smooth_fluor_s, fluor_d, marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[2][1].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')

    # print('profile time range', str(time0)[:16], 'to', str(time1)[:16])
    
    return axs
    

from matplotlib import animation, rc
from IPython.display import HTML, Video

# prior code
# Writer = animation.writers['ffmpeg']
# writer = Writer(fps=1, metadata=dict(artist='Rob'), bitrate=1800)
# ShowSixCharts(130)

ani = animation.FuncAnimation(fig, ShowSixCharts, interval=50, frames=15, repeat=True, blit=True) # frames > 278
ani.save('osb15.mp4')    # prior code added , writer=writer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4300d636793b> in <module>
#      67 # ShowSixCharts(130)
#      68
# ---> 69 ani = animation.FuncAnimation(fig, ShowSixCharts, interval=50, frames=15, repeat=True, blit=True) # frames > 278
#      70 ani.save('osb15.mp4')    # prior code added , writer=writer)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1654         self._save_seq = []
#    1655
# -> 1656         TimedAnimation.__init__(self, fig, **kwargs)
#    1657
#    1658         # Need to reset the saved seq, since right now it will contain data
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1413         if event_source is None:
#    1414             event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1415         Animation.__init__(self, fig, event_source=event_source,
#    1416                            *args, **kwargs)
#    1417
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in __init__(self, fig, event_source, blit)
#     943                                                       self._stop)
#     944         if self._blit:
# --> 945             self._setup_blit()
#     946
#     947     def _start(self, *args):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _setup_blit(self)
#    1247         self._resize_id = self._fig.canvas.mpl_connect('resize_event',
#    1248                                                        self._on_resize)
# -> 1249         self._post_draw(None, self._blit)
#    1250
#    1251     def _on_resize(self, event):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1200             self._blit_draw(self._drawn_artists)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#    1204     # The rest of the code in this class is to facilitate easy blitting
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1868             self.stale = False
#    1869
# -> 1870         self.canvas.draw_event(renderer)
#    1871
#    1872     def draw_artist(self, a):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in draw_event(self, renderer)
#    1757         s = 'draw_event'
#    1758         event = DrawEvent(s, self, renderer)
# -> 1759         self.callbacks.process(s, event)
#    1760
#    1761     def resize_event(self):
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     227                 except Exception as exc:
#     228                     if self.exception_handler is not None:
# --> 229                         self.exception_handler(exc)
#     230                     else:
#     231                         raise
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      79 def _exception_printer(exc):
#      80     if _get_running_interactive_framework() in ["headless", None]:
# ---> 81         raise exc
#      82     else:
#      83         traceback.print_exc()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     222             if func is not None:
#     223                 try:
# --> 224                     func(*args, **kwargs)
#     225                 # this does not capture KeyboardInterrupt, SystemExit,
#     226                 # and GeneratorExit
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _start(self, *args)
#     957
#     958         # Now do any initial draw
# --> 959         self._init_draw()
#     960
#     961         # Add our callback for stepping the animation and
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _init_draw(self)
#    1701         # artists.
#    1702         if self._init_func is None:
# -> 1703             self._draw_frame(next(self.new_frame_seq()))
#    1704
#    1705         else:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1729                 raise RuntimeError('The animation function must return a '
#    1730                                    'sequence of Artist objects.')
# -> 1731             self._drawn_artists = sorted(self._drawn_artists,
#    1732                                          key=lambda x: x.get_zorder())
#    1733
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/animation.py in <lambda>(x)
#    1730                                    'sequence of Artist objects.')
#    1731             self._drawn_artists = sorted(self._drawn_artists,
# -> 1732                                          key=lambda x: x.get_zorder())
#    1733
#    1734             for a in self._drawn_artists:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'get_zorder'

# %%
Video("./osb15.mp4")           # can include embed=True
# Out:
# <video src="./osb15.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Data charting part 2: slider selection of profiles
#
# This section takes the above results and provides a slider to drag through all 278 profiles in January 2019.
#
# To see differentiation of these curves: Drop down to the next segment.

# %%
from ipywidgets import *
from traitlets import dlink

# %%
def ProfileChoicesChart(ctd, fluor, t, nf = 1):
    """
    Plot comparative charts for two or more profiles: CTD x 3, fluorescence x 3; left and
    right; based on time ranges in t[0, 1, 2, 3][i]; using the 'hat' filter with param nf
    """
    
    # t is a list of four lists so the slow / left index refers as 0, 1, 2, 3 to:
    #   left begin-time, left end-time, right begin-time, right end-time
    # Each of these four elements is a list of times corresponding to multiple profiles
    #   By choosing a slider value > 1 we can overplot sets of consecutive profiles
    
    nLeft = len(t[0])
    if not nLeft == len(t[1]): print('profile count mismatch left side'); return
    nRight = len(t[2])
    if not nRight == len(t[3]): print('profile count mismatch right side'); return
    
    temperature_lbound, temperature_ubound           =   8.,        12.
    salinity_lbound, salinity_ubound                 =  32.,        34.
    dissolved_oxygen_lbound, dissolved_oxygen_ubound = 100.,       300.
    chlora_lbound, chlora_ubound                     =  -1.,         2.
    cdom_lbound, cdom_ubound                         =   1.2,        2.2
    scatt_lbound, scatt_ubound                       =   0.000075,    .00035

    fig, axs = plt.subplots(6,2,figsize=(16, 15), tight_layout=True)

    for left in range(nLeft):
        left off with this stuff before the sets...
        ctd_slice   = [ctd.sel(time=slice(t[0][0], t[1][0])),   ctd.sel(time=slice(t[2][0], t[3][0]))]
        fluor_slice = [fluor.sel(time=slice(t[0][0], t[1][0])), fluor.sel(time=slice(t[2][0], t[3][0]))]

        ctd_t = [ctd_slice[0]['seawater_temperature'],       ctd_slice[1]['seawater_temperature']      ]   
        ctd_s = [ctd_slice[0]['practical_salinity'],         ctd_slice[1]['practical_salinity']        ]
        ctd_o = [ctd_slice[0]['corrected_dissolved_oxygen'], ctd_slice[1]['corrected_dissolved_oxygen']]

        fluor_a = [fluor_slice[0]['fluorometric_chlorophyll_a'],          
                   fluor_slice[1]['fluorometric_chlorophyll_a']]
        fluor_c = [fluor_slice[0]['fluorometric_cdom'],                   
                   fluor_slice[1]['fluorometric_cdom']]
        fluor_s = [fluor_slice[0]['total_volume_scattering_coefficient'], 
                   fluor_slice[1]['total_volume_scattering_coefficient']]

        ctd_t_filt = [filter(ctd_t[0], 'hat', nf), filter(ctd_t[1], 'hat', nf)]
        ctd_s_filt = [filter(ctd_s[0], 'hat', nf), filter(ctd_s[1], 'hat', nf)]
        ctd_o_filt = [filter(ctd_o[0], 'hat', nf), filter(ctd_o[1], 'hat', nf)]

        fluor_a_filt = [filter(fluor_a[0], 'hat', nf), filter(fluor_a[1], 'hat', nf)]
        fluor_c_filt = [filter(fluor_c[0], 'hat', nf), filter(fluor_c[1], 'hat', nf)]
        fluor_s_filt = [filter(fluor_s[0], 'hat', nf), filter(fluor_s[1], 'hat', nf)]

        ctd_d   = [ctd_slice[0]['seawater_pressure'], ctd_slice[1]['seawater_pressure']]
        fluor_d = [fluor_slice[0]['int_ctd_pressure'], fluor_slice[1]['int_ctd_pressure']]

        axs[0][0].plot(ctd_t_filt[0], ctd_d[0], marker='o', markersize = 6., color='k', markerfacecolor='c')
        axs[1][0].plot(ctd_s_filt[0], ctd_d[0], marker='s', markersize = 6., color='g', markerfacecolor='m')
        axs[2][0].plot(ctd_o_filt[0], ctd_d[0], marker='D', markersize = 6., color='b', markerfacecolor='y')
        axs[3][0].plot(fluor_a_filt[0], fluor_d[0], marker='o', markersize = 6., color='k', markerfacecolor='c')
        axs[4][0].plot(fluor_c_filt[0], fluor_d[0], marker='s', markersize = 6., color='g', markerfacecolor='m')
        axs[5][0].plot(fluor_s_filt[0], fluor_d[0], marker='D', markersize = 6., color='b', markerfacecolor='y')

    axs[0][0].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')
    axs[1][0].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')
    axs[2][0].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')
    axs[3][0].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')
    axs[4][0].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')
    axs[5][0].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')

        
        axs[0][1].plot(ctd_t_filt[1], ctd_d[1], marker='o', markersize = 6., color='k', markerfacecolor='c')
        axs[0][1].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')
        axs[1][1].plot(ctd_s_filt[1], ctd_d[1], marker='s', markersize = 6., color='g', markerfacecolor='m')
        axs[1][1].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')
        axs[2][1].plot(ctd_o_filt[1], ctd_d[1], marker='D', markersize = 6., color='b', markerfacecolor='y')
        axs[2][1].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')
        axs[3][1].plot(fluor_a_filt[1], fluor_d[1], marker='o', markersize = 6., color='k', markerfacecolor='c')
        axs[3][1].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')
        axs[4][1].plot(fluor_c_filt[1], fluor_d[1], marker='s', markersize = 6., color='g', markerfacecolor='m')
        axs[4][1].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')
        axs[5][1].plot(fluor_s_filt[1], fluor_d[1], marker='D', markersize = 6., color='b', markerfacecolor='y')
        axs[5][1].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')

    
    
    
    for right in range(nRight):
    
    
    ctd_slice   = [ctd.sel(time=slice(t[0][0], t[1][0])),   ctd.sel(time=slice(t[2][0], t[3][0]))]
    fluor_slice = [fluor.sel(time=slice(t[0][0], t[1][0])), fluor.sel(time=slice(t[2][0], t[3][0]))]

    ctd_t = [ctd_slice[0]['seawater_temperature'],       ctd_slice[1]['seawater_temperature']      ]   
    ctd_s = [ctd_slice[0]['practical_salinity'],         ctd_slice[1]['practical_salinity']        ]
    ctd_o = [ctd_slice[0]['corrected_dissolved_oxygen'], ctd_slice[1]['corrected_dissolved_oxygen']]
    
    fluor_a = [fluor_slice[0]['fluorometric_chlorophyll_a'],          
               fluor_slice[1]['fluorometric_chlorophyll_a']]
    fluor_c = [fluor_slice[0]['fluorometric_cdom'],                   
               fluor_slice[1]['fluorometric_cdom']]
    fluor_s = [fluor_slice[0]['total_volume_scattering_coefficient'], 
               fluor_slice[1]['total_volume_scattering_coefficient']]
    
    ctd_t_filt = [filter(ctd_t[0], 'hat', nf), filter(ctd_t[1], 'hat', nf)]
    ctd_s_filt = [filter(ctd_s[0], 'hat', nf), filter(ctd_s[1], 'hat', nf)]
    ctd_o_filt = [filter(ctd_o[0], 'hat', nf), filter(ctd_o[1], 'hat', nf)]
               
    fluor_a_filt = [filter(fluor_a[0], 'hat', nf), filter(fluor_a[1], 'hat', nf)]
    fluor_c_filt = [filter(fluor_c[0], 'hat', nf), filter(fluor_c[1], 'hat', nf)]
    fluor_s_filt = [filter(fluor_s[0], 'hat', nf), filter(fluor_s[1], 'hat', nf)]
               
    ctd_d   = [ctd_slice[0]['seawater_pressure'], ctd_slice[1]['seawater_pressure']]
    fluor_d = [fluor_slice[0]['int_ctd_pressure'], fluor_slice[1]['int_ctd_pressure']]

    temperature_lbound, temperature_ubound           =   8.,        12.
    salinity_lbound, salinity_ubound                 =  32.,        34.
    dissolved_oxygen_lbound, dissolved_oxygen_ubound = 100.,       300.
    chlora_lbound, chlora_ubound                     =  -1.,         2.
    cdom_lbound, cdom_ubound                         =   1.2,        2.2
    scatt_lbound, scatt_ubound                       =   0.000075,    .00035

    fig, axs = plt.subplots(6,2,figsize=(16, 15), tight_layout=True)

    axs[0][0].plot(ctd_t_filt[0], ctd_d[0], marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[0][0].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')
    axs[1][0].plot(ctd_s_filt[0], ctd_d[0], marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[1][0].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')
    axs[2][0].plot(ctd_o_filt[0], ctd_d[0], marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[2][0].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')
    axs[3][0].plot(fluor_a_filt[0], fluor_d[0], marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[3][0].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')
    axs[4][0].plot(fluor_c_filt[0], fluor_d[0], marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[4][0].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')
    axs[5][0].plot(fluor_s_filt[0], fluor_d[0], marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[5][0].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')

    axs[0][1].plot(ctd_t_filt[1], ctd_d[1], marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[0][1].set(xlim = (temperature_lbound, temperature_ubound), ylim = (200., 0.), title='temperature')
    axs[1][1].plot(ctd_s_filt[1], ctd_d[1], marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[1][1].set(xlim = (salinity_lbound, salinity_ubound), ylim = (200., 0.), title='salinity')
    axs[2][1].plot(ctd_o_filt[1], ctd_d[1], marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[2][1].set(xlim = (dissolved_oxygen_lbound, dissolved_oxygen_ubound), ylim = (200., 0.), title='dissolved oxygen')
    axs[3][1].plot(fluor_a_filt[1], fluor_d[1], marker='o', markersize = 6., color='k', markerfacecolor='c')
    axs[3][1].set(xlim = (chlora_lbound, chlora_ubound), ylim = (200., 0.), title='chlorophyll a')
    axs[4][1].plot(fluor_c_filt[1], fluor_d[1], marker='s', markersize = 6., color='g', markerfacecolor='m')
    axs[4][1].set(xlim = (cdom_lbound, cdom_ubound), ylim = (200., 0.), title='cdom')
    axs[5][1].plot(fluor_s_filt[1], fluor_d[1], marker='D', markersize = 6., color='b', markerfacecolor='y')
    axs[5][1].set(xlim = (scatt_lbound, scatt_ubound), ylim = (200., 0.), title='total volume backscatter')
    
    print('left profile', str(t[0][0])[:16], 'to', str(t[1][0])[:16], \
          '... right profile', str(t[2][0])[:16], 'to', str(t[3][0])[:16])
    return

left0, right0 = 0, 1

t00 = dt64(ds_CTD.time[ascent0[left0]].data)   
t01 = dt64(ds_CTD.time[ascent1[left0]].data)   
t10 = dt64(ds_CTD.time[ascent0[right0]].data)   
t11 = dt64(ds_CTD.time[ascent1[right0]].data) 

nProfiles = len(ascent0)

def SliderRelay(firstLeft, nLeft, firstRight, nRight):
    global t00, t01, t10, t11, ds_CTD, ds_Fluorometer  
    t00 = [dt64(ds_CTD.time[ascent0[i]].data) for i in range(firstLeft, firstLeft + nLeft)]
    t01 = [dt64(ds_CTD.time[ascent1[i]].data) for i in range(firstLeft, firstLeft + nLeft)]   
    t10 = [dt64(ds_CTD.time[ascent0[i]].data) for i in range(firstRight, firstRight + nRight)]
    t11 = [dt64(ds_CTD.time[ascent1[i]].data) for i in range(firstRight, firstRight + nRight)]
    ProfileChoicesChart(ds_CTD, ds_Fluorometer, [t00, t01, t10,t11], 1)


interact(SliderRelay, firstLeft=widgets.IntSlider(min=0, max=nProfiles-1, step=1, value=left0, \
                                          continuous_update=False, description='1st prof left'), \
                      nLeft=widgets.IntSlider(min=1, max=nProfiles-1, step=1, value=1, \
                                          continuous_update=False, description='n-prof left'), \
                      firstRight=widgets.IntSlider(min=0, max=nProfiles-1, step=1, value=right0, \
                                       continuous_update=False, description='1st prof right'), \
                      nRight=widgets.IntSlider(min=1, max=nProfiles-1, step=1, value=1, \
                                          continuous_update=False, description='n-prof right')\
        )
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='1st prof left', max=277), IntSl…
# <function __main__.SliderRelay(firstLeft, nLeft, firstRight, nRight)>

# %% [markdown]
# ## differentiation of profile curves
#
# The idea here is to look at first and second derivatives as a way of characterizing / segmenting profiles.

# %%
dydx1_t = dydx(smooth_t, sensor_d)
dydx2_t = dydx(dydx1_t, sensor_d)
dydx1_s = dydx(smooth_s, sensor_d)
dydx2_s = dydx(dydx1_s, sensor_d)
dydx1_o = dydx(smooth_o, sensor_d)
dydx2_o = dydx(dydx1_o, sensor_d)

fig, axs = plt.subplots(3,1,figsize=(15,18), tight_layout=True)

axs[0].plot(dydx1_t, sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='g')
axs[0].plot(dydx2_t*np.ones(71)*4+0.2, sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='b')
axs[0].set(xlim = (-.05, .3), ylim = (200., 0.))

axs[1].plot(dydx1_s, sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='r')
axs[1].plot(dydx2_s*np.ones(71)*4+0.1, sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='y')
axs[1].set(xlim = (-.1, .2), ylim = (200., 0.))

axs[2].plot(dydx1_o, sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='c')
axs[2].plot(dydx2_o*np.ones(71)*4+4., sensor_d, marker='o', markersize = 9., color='k', markerfacecolor='m')
axs[2].set(xlim = (-1, 6.), ylim = (200., 0.))
# Out:
# [(-1.0, 6.0), (200.0, 0.0)]

# %%
sensor_d[-1]
# Out:
# <xarray.DataArray 'seawater_pressure' ()>
# array(6.618323)
# Coordinates:
#     time     datetime64[ns] 2019-01-01T01:37:00
# Attributes:
#     comment:                  Seawater Pressure refers to the pressure exerte...
#     long_name:                Seawater Pressure
#     precision:                3
#     data_product_identifier:  PRESWAT_L1
#     standard_name:            sea_water_pressure
#     units:                    dbar
#     ancillary_variables:      pressure,pressure_temp
#     axis:                     Z

# %% [markdown]
# ## Profile as a class
#
# The idea here is to create a Python class 'Profile' that can be used to organize many profiles.

# %%
class Profile:
    """A water column profile"""
    
    def __init__(self, t0='2019-01-01T00:26:05', t1='2019-01-01T01:37:55', d0=191.268063, d1=6.618323, site='osb'):
        self.t0 = dt64(t0)
        self.t1 = dt64(t1)
        self.d0 = d0
        self.d1 = d1
        self.site = site

    def readout(self):
        print("Profile start", self.t0, 'duration', self.t1 - self.t0)

p = Profile()
p.readout()
# Out:
# Profile start 2019-01-01T00:26:05 duration 4310 seconds

# %% [markdown]
# ## How many profiles ran in January 2019?
#
# At nine per day and 31 days we should have 279 profiles. The Crawler finds only 278 so either the
# algorithm is faulty or a profile was skipped. By looking at the depth chart we see it is the latter case.

# %%
# January 2019 has all but one profile correct (278 / 279 possible). 
#   Missing is the last profile of the month.
# For each given UTC day: Profiles 4 and 9 are pH profiles.
#   Could use time window criteria: Hour on [6, 10] and [19, 23].

fig, axs = plt.subplots(16, 1, figsize=(15,31), tight_layout=True)

for i in range(31):
    daystring = str(i+1) if i > 8 else '0' + str(i+1)
    time0, time1 = '2019-01-' + daystring + 'T00:00:00', '2019-01-' + daystring + 'T23:59:59'
    ds = ds_CTD.sel(time=slice(time0, time1))
    axs[i].plot(ds.time, ds.seawater_pressure, marker='.', markersize=1., color='k')
    axs[i].set(ylim = (200., 0.))

print('...January 2019 OSB depth profiles...')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-700a27e4a962> in <module>
#      10     time0, time1 = '2019-01-' + daystring + 'T00:00:00', '2019-01-' + daystring + 'T23:59:59'
#      11     ds = ds_CTD.sel(time=slice(time0, time1))
# ---> 12     axs[i].plot(ds.time, ds.seawater_pressure, marker='.', markersize=1., color='k')
#      13     axs[i].set(ylim = (200., 0.))
#      14
#
# IndexError: index 16 is out of bounds for axis 0 with size 16
